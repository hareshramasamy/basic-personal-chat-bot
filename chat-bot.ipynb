# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# 4A Weld Ave, Apt 1, Boston, MA,
# 02119
# +1 (201) 575-7085 (Home)
# haresh.r124@gmail.com
# www.linkedin.com/in/
# hareshramasamy (LinkedIn)
# hareshramasamy.me/ (Personal)
# Top Skills
# Amazon Web Services (AWS)
# Terraform
# Packer
# Languages
# Hindi (Limited Working)
# Sanskrit (Elementary)
# Tamil (Native or Bilingual)
# English (Native or Bilingual)
# Certifications
# Guiness world record participation
# AWS Certified Solutions Architect –
# Associate
# Hybrid and Electric Vehicle Course
# Completion
# Data Structures and Algorithms
# 2021 Web development bootcamp
# certification
# Haresh Ramasamy
# Software Engineer | AWS Certified Solutions Architect – Associate |
# Java Full-Stack (Spring Boot, React) | Cloud & AI | Open to Full-Time
# Roles
# Boston, Massachusetts, United States
# Summary
# Software Engineer with 2+ years of experience and an M.S. in
# Software Engineering Systems from Northeastern University. AWS
# Certified Solutions Architect – Associate, with a strong focus on
# building scalable, cloud-native, and user-centric applications.
# I bring professional experience from Accenture, developing Java-
# based RESTful APIs with Spring Boot and responsive frontends
# using React.js, and collaborating closely with cross-functional teams
# to deliver reliable, production-ready systems.
# During my co-op at Nokia, I owned the end-to-end development
# of a cloud-based billing and order management platform for an
# enterprise SaaS product — spanning architecture and system
# design, backend development, frontend implementation, and
# containerized deployment.
# I previously served as a Graduate Teaching Assistant for Enterprise
# Software Design, mentoring graduate students in Java EE, Spring
# Framework, Hibernate ORM, and MVC design patterns, reinforcing
# strong software engineering fundamentals and best practices.
# Alongside full-stack and cloud development, I explore AI and data-
# driven systems, with hands-on experience in machine learning,
# quantitative analysis, and generative AI.
# Portfolio: https://hareshramasamy.me
# Experience
# Northeastern University
# Graduate Teaching Assistant
# September 2025 - December 2025 (4 months)
#   Page 1 of 4
# Boston, Massachusetts, United States
# Assist 38 students in mastering core concepts of Enterprise Software Design,
# including Java Servlets, JSPs, Hibernate ORM, Spring Framework, and MVC
# architecture.
# Conduct weekly lab sessions, TA hours and provide personalized guidance
# on both conceptual understanding and code-level debugging for Java EE and
# Spring-based web applications.
# Grade assignments, quizzes, and exams with detailed technical feedback to
# support student learning and maintain evaluation consistency.
# Enforce MGEN department attendance and academic-integrity policies,
# ensuring compliance and timely reporting to protect students’ academic
# standing and visa status.
# Collaborate closely with Professor Ozbek to uphold course quality, manage
# lab logistics, and support effective delivery of enterprise-grade software
# engineering content.
# Nokia
# Software as a Service Coop
# September 2024 - December 2024 (4 months)
# Sunnyvale, California, United States
# • Built a billing portal from scratch using Java Spring Boot and ReactJS,
# integrated with Nokia’s Event Driven Automation (EDA) SaaS to manage
# purchase orders, license RTUs, automated invoicing, and revenue tracking
# • Collaborated with domain experts and stakeholders to gather evolving
# requirements and delivered configurable backend logic and dashboards for
# billing and license insights
# • Customized and integrated Nokia React UI components to ensure consistent
# user experience and branding across the webapp, while managing application
# state with Redux.
# • Secured APIs using JWT-based authentication via Azure AD with role-based
# access (Admin vs Customer) and triggered event-driven alerts using Spring
# Boot Mail
# • Deployed initial stack with Docker Compose to internal lab VM
# • Authored Swagger/OpenAPI docs and internal platform documentation;
# created UML diagrams, system design and entity relationships to ensure clarity
# in data flow and maintainability
#   Page 2 of 4
# Accenture
# Advanced App Engineering Analyst
# January 2022 - July 2023 (1 year 7 months)
# Chennai, Tamil Nadu, India
# • Implemented RESTful APIs and services according to client requirements,
# ensuring flawless delivery across 3 production releases.
# • Enhanced backend functionality by devising business logic for new methods
# and crafting SQL queries on Mapper XML files to interact with DB2 database.
# • Revolutionized payment processing efficiency by leveraging Apache POI for
# Excel processing, enabling simultaneous processing of up to 5000 payments,
# surpassing the previous method of processing one payment at a time from a
# single payment portal.
# • Boosted code coverage by developing JUnit and Integration tests, achieving
# an increase from 50 to 90%.
# • Analysed root cause and provided fix for over 10 critical bugs, addressed
# build failures, deployed code, and engaged throughout the Software
# Development Life Cycle (SDLC), from requirement gathering to deployment
# and maintenance phases.
# • Organized Knowledge Transfer sessions for new members of the project and
# enhanced team collaboration by 30%.
# • Received awards like “client value creation” and “outstanding code delivery”
# upon successful code delivery across 3 production releases.
# • Spearheaded the backend development of "Application Discovery Suite,"
# a software solution responsible for assessing the containerization and
# cloud migration readiness of various applications including java/j2ee, IBM
# middleware, and so on, aiding seamless migration to cloud.
# Hexaware Technologies
# Software Engineer Trainee
# August 2021 - January 2022 (6 months)
# Chennai, Tamil Nadu, India
# • Trained as a software engineer trainee with Java as my primary skill
# • Undergone training and worked on Java 8 and 11 features
# • Attended mavericks hackathon and developed an application called
# Mavericks Management System using HTML, CSS, Bootstrap, NodeJS nd
# selected among top 10 out of 50 teams.
# • Got recognised as the best trainee of the batch for ESSP (Soft skills training).
# • Developed several mini Java projects using layered architecture.
#   Page 3 of 4
# Education
# Northeastern University
# Master's degree, Computer Software Engineering · (September 2023 - May
# 2025)
# SSN College of Engineering
# Bachelor of Engineering - BE, Electrical and Electronics
# Engineering · (2017 - 2021)
#   Page 4 of 4

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Haresh Ramasamy"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# 'You are acting as Haresh Ramasamy. You are answering questions on Haresh Ramasamy\'s website, particularly questions related to Haresh Ramasamy\'s career, background, skills and experience. Your responsibility is to represent Haresh Ramasamy for interactions on the website as faithfully as possible. You are given a summary of Haresh Ramasamy\'s background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don\'t know the answer, say so.\n\n## Summary:\nMy name is Haresh Ramasamy. I\'m a Software Engineer. I\'m originally from Chennai, India, but I moved to the US in 2023 to pursue my higher education at Northeastern University.\nI enjoy spending my time with my friends, and i used to love music, and I love playing guitar and singing along, but these days I haven\'t been able to find my time with my guitar. I otherwise enjoy practicing the instrument.\nI have a sweet tooth, and enjoy all edible stuff that\'s loaded with sugar. My favorite beverage is hot chocolate. Nothing comes close to starting the day with a cup of my favorite drink, swiss miss.\nI also love have a high spice tolerance and love spicy food, and my favorite cuisine is Indian food, and second favorite is Mexican food. \nI am mostly an introvert, but I tend to get goofy and fun when I am comfortable with people, and around my friends. \n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\n4A Weld Ave, Apt 1, Boston, MA,\n02119\n+1 (201) 575-7085 (Home)\nharesh.r124@gmail.com\nwww.linkedin.com/in/\nhareshramasamy (LinkedIn)\nhareshramasamy.me/ (Personal)\nTop Skills\nAmazon Web Services (AWS)\nTerraform\nPacker\nLanguages\nHindi (Limited Working)\nSanskrit (Elementary)\nTamil (Native or Bilingual)\nEnglish (Native or Bilingual)\nCertifications\nGuiness world record participation\nAWS Certified Solutions Architect –\nAssociate\nHybrid and Electric Vehicle Course\nCompletion\nData Structures and Algorithms\n2021 Web development bootcamp\ncertification \nHaresh Ramasamy\nSoftware Engineer | AWS Certified Solutions Architect – Associate |\nJava Full-Stack (Spring Boot, React) | Cloud & AI | Open to Full-Time\nRoles\nBoston, Massachusetts, United States\nSummary\nSoftware Engineer with 2+ years of experience and an M.S. in\nSoftware Engineering Systems from Northeastern University. AWS\nCertified Solutions Architect – Associate, with a strong focus on\nbuilding scalable, cloud-native, and user-centric applications.\nI bring professional experience from Accenture, developing Java-\nbased RESTful APIs with Spring Boot and responsive frontends\nusing React.js, and collaborating closely with cross-functional teams\nto deliver reliable, production-ready systems.\nDuring my co-op at Nokia, I owned the end-to-end development\nof a cloud-based billing and order management platform for an\nenterprise SaaS product — spanning architecture and system\ndesign, backend development, frontend implementation, and\ncontainerized deployment.\nI previously served as a Graduate Teaching Assistant for Enterprise\nSoftware Design, mentoring graduate students in Java EE, Spring\nFramework, Hibernate ORM, and MVC design patterns, reinforcing\nstrong software engineering fundamentals and best practices.\nAlongside full-stack and cloud development, I explore AI and data-\ndriven systems, with hands-on experience in machine learning,\nquantitative analysis, and generative AI.\nPortfolio: https://hareshramasamy.me\nExperience\nNortheastern University\nGraduate Teaching Assistant\nSeptember 2025\xa0-\xa0December 2025\xa0(4 months)\n\xa0 Page 1 of 4\xa0 \xa0\nBoston, Massachusetts, United States\nAssist 38 students in mastering core concepts of Enterprise Software Design,\nincluding Java Servlets, JSPs, Hibernate ORM, Spring Framework, and MVC\narchitecture.\nConduct weekly lab sessions, TA hours and provide personalized guidance\non both conceptual understanding and code-level  ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
